# %%
import os, re
import pandas as pd
pd.set_option("display.max_rows", 500)

# name for analysis running
ANALYSIS_NAME = "core1"

""" 
YOUR PARAMETERS - CHANGE THESE!

STEP1:
Put your MIDI files into the folder final_datasets/

STEP2:
Make sure your MIDI files have standardized naming, specifically, have
a common substring in the filename <MUSIC_FILE_REGEX>.
*If you include structural break tagging, add your tagging MIDI file
as <original_filename>_TAGGED_<time_series_name>.mid.
Example for MUSIC_FILE_REGEX="kapustin_variations":
    - kapustin_variations.mid:
        original MIDI file
    - kapustin_variations.wav:
        WAV file to accompany original MIDI
    - kapustin_variations_TAGGED_pitch_mean.mid:
        structural break tagging information for kapustin_variations.mid
    - kapustin_variations_TAGGED_pitch_mean.wav:
        WAV file to accompany tagging information
        (= original + tagging audio)

STEP3:
Change parameters here. Again, note that the string <MUSIC_FILE_REGEX>
will be used to filter for all MIDI files to analyze.
- corpus: name for corpus (only for output naming)
- music file regex: for searching pieces in final_datasets
- time series variable: time series to analyze (see available below)
"""

CORPUS = "saarland"
# IMPORTANT: should at most match 1 MIDI file in final_datasets/
MUSIC_FILE_REGEX = "Bach_BWV849-01"
TIME_SERIES_VARIABLE = "pitch_mean"

### other metadata
PIECE_NAME = "{}".format(MUSIC_FILE_REGEX)
PIANIST = "Saarland"
DATE = "May 1, 2021"

""""""

ANALYSIS_KEY = '__'.join([ANALYSIS_NAME, CORPUS, MUSIC_FILE_REGEX, TIME_SERIES_VARIABLE])
TIME_SERIES_VARIABLE_FMT = TIME_SERIES_VARIABLE.replace("_", " ").title()

### All structural break tagging MIDI fileswill have this in the filename
### For instance, "kapustin_variations_BEAT.midi" will be a structural break tagging file
### for the core music file "kapustin_variations.midi"
STRUCTURAL_BREAK_REGEX = "TAGGED"

### Use only the first filename that shows up. This notebook is only
### designed to find and run on 1 piece.
USE_ONLY_FIRST_MIDI_STREAM = True

### Validate time series variable:
### Should be one of the following
time_series_variables = ['n_notes',
 'pitch_min', 'pitch_mean', 'pitch_median', 'pitch_max',
 'velocity_min', 'velocity_mean', 'velocity_median', 'velocity_max',
 'duration_min', 'duration_mean', 'duration_median', 'duration_max']
if TIME_SERIES_VARIABLE not in time_series_variables:
    raise Exception("Time series variable not found.")

### Set up overall folder for task 1
### Analysis will use and concatenate all the MIDI tracks of interest in this folder,
### where tracks of interest have MIDI_STREAM_REGEX in filename.
INPUT_FOLDER = "final_datasets"
MIDI_STREAM_REGEX = MUSIC_FILE_REGEX
add_input_folder = lambda x: "{}/{}".format(INPUT_FOLDER, x).replace("//", "/")
print(INPUT_FOLDER)

# ### Output will be stored in folder (and subfolders of):
# ### results/<ANALYSIS_NAME>/<CORPUS>/<MUSIC_FILE_REGEX>/<TIME_SERIES_VARIABLE>
# OUTPUT_FOLDER = "results"
# if not os.path.exists(OUTPUT_FOLDER):
#     os.mkdir(OUTPUT_FOLDER)
# for v in [ANALYSIS_NAME, CORPUS, MUSIC_FILE_REGEX, TIME_SERIES_VARIABLE]:
#     OUTPUT_FOLDER = "{}/{}".format(OUTPUT_FOLDER, v)
#     if not os.path.exists(OUTPUT_FOLDER):
#         os.mkdir(OUTPUT_FOLDER)
# add_output_path = lambda x: "{}/{}".format(OUTPUT_FOLDER, x)
# print(OUTPUT_FOLDER)
# Out:
# final_datasets

# %% [markdown]
# ### Read in all summary and error files

# %%
""" Summary of error """
import fnmatch
import os
import numpy as np

matches = []
for root, dirnames, filenames in os.walk('results'):
    for filename in fnmatch.filter(filenames, 'summary_error.csv'):
        matches.append(os.path.join(root, filename))
print("\n".join(matches))

all_summary_error = []
for match in matches:
    df_curr = pd.read_csv(match, header=[0,1], skiprows=1)
    df_curr.columns = ["model_no", "reg_model", "change_model", "n", "MSE", "RMSE", "MAE", "MAPE", "analysis_key"]
    df_info = pd.DataFrame(df_curr.analysis_key.str.split("__", expand=True))
    df_info2 = pd.DataFrame(df_info[2].str.split("_", expand=True)).loc[:,[0,1]]
    df_curr = pd.concat([df_curr,df_info, df_info2], axis=1)
    df_curr.columns = (["model_no", "reg_model", "change_model", "n", "MSE", "RMSE", "MAE", "MAPE", "analysis_key"] +
        ['key', 'corpus', 'work', 'series', 'composer', 'piece'])
    df_curr = df_curr[["model_no", "reg_model", "change_model", "MSE", "RMSE", "MAE", "MAPE",
                      "composer", "piece", "series"]]
    all_summary_error.append(df_curr)

df_all_summary_error = pd.concat(all_summary_error).round(3)
df_all_summary_error = df_all_summary_error[['composer', 'piece', 'reg_model', 'change_model',
                            'MSE', 'RMSE', 'MAE', 'MAPE']]
# agg
def percentile(n):
    def percentile_(x):
        return np.percentile(x, n)
    percentile_.__name__ = 'percentile_%s' % n
    return percentile_
df_all_summary_error_agg = df_all_summary_error.groupby((['reg_model', 'change_model'])).agg({
    "MSE": [np.mean, np.median],
    "RMSE": [np.mean, np.median],
    "MAE": [np.mean, np.median],
    "MAPE": [np.mean, np.median]
}).reset_index().round(3).sort_values(by=['reg_model', 'change_model'])
df_all_summary_error_agg.columns = [" ".join(c).replace("reg_model", "Model")
                                        .replace("change_model", "Change point method").strip()
                                    for c in df_all_summary_error_agg.columns]
df_all_summary_error_agg.Model = df_all_summary_error_agg.Model.astype("category")
df_all_summary_error_agg['Model'].cat.set_categories(['Bayesian LR', 'Kalman Filter', 'Gaussian process regression',
                                                 'Recursive ridge regression'], inplace=True)
df_all_summary_error_agg = df_all_summary_error_agg.sort_values(by=['Model'])
# Gaussian process - default in SKLEARN
display(df_all_summary_error_agg)
print(df_all_summary_error_agg.shape)
print(df_all_summary_error_agg.to_latex(index=False))

display(df_all_summary_error)
print(df_all_summary_error.shape)
print(df_all_summary_error.to_latex(index=False))
# Out:
# results\core1\chow\kapustin_variations\pitch_mean\step3\summary_error.csv
# results\core1\saarland\Bach_BWV849-01\pitch_mean\step3\summary_error.csv
# results\core1\saarland\Beethoven_Op027No1-01\pitch_mean\step3\summary_error.csv
# results\core1\saarland\Chopin_Op010-03\pitch_mean\step3\summary_error.csv
# results\core1\saarland\Haydn_HobXVINo52-01\pitch_mean\step3\summary_error.csv
# results\core1\saarland\Liszt_AnnesDePelerinage-LectureDante\pitch_mean\step3\summary_error.csv
# results\core1\saarland\Mozart_KV265_006\pitch_mean\step3\summary_error.csv
# results\core1\saarland\Rachmaninoff_Op036-01\pitch_mean\step3\summary_error.csv
# results\core1\saarland\Ravel_JeuxDEau_008\pitch_mean\step3\summary_error.csv
#                          Model Change point method  MSE mean  MSE median  \
# 0                  Bayesian LR                BOCD    56.831      55.674
# 1                  Bayesian LR               CUSUM    56.831      55.674
# 4                Kalman Filter                BOCD    66.967      64.798
# 5                Kalman Filter               CUSUM    66.967      64.798
# 2  Gaussian process regression                BOCD   128.631      83.495
# 3  Gaussian process regression               CUSUM   128.631      83.495
# 6   Recursive ridge regression                BOCD  1063.720     289.335
# 7   Recursive ridge regression               CUSUM  1063.720     289.335
#
#    RMSE mean  RMSE median  MAE mean  MAE median  MAPE mean  MAPE median
# 0      7.454        7.461     5.557       5.667      9.022        9.226
# 1      7.454        7.461     5.557       5.667      9.022        9.226
# 4      8.057        8.050     6.304       6.338     10.313       10.586
# 5      8.057        8.050     6.304       6.338     10.313       10.586
# 2     10.509        9.138     8.202       7.341     13.148       11.842
# 3     10.509        9.138     8.202       7.341     13.148       11.842
# 6     27.859       17.010    20.513      12.939     32.139       18.521
# 7     27.859       17.010    20.513      12.939     32.139       18.521
# (8, 10)
# \begin{tabular}{llrrrrrrrr}
# \toprule
#                       Model & Change point method &  MSE mean &  MSE median &  RMSE mean &  RMSE median &  MAE mean &  MAE median &  MAPE mean &  MAPE median \\
# \midrule
#                 Bayesian LR &                BOCD &    56.831 &      55.674 &      7.454 &        7.461 &     5.557 &       5.667 &      9.022 &        9.226 \\
#                 Bayesian LR &               CUSUM &    56.831 &      55.674 &      7.454 &        7.461 &     5.557 &       5.667 &      9.022 &        9.226 \\
#               Kalman Filter &                BOCD &    66.967 &      64.798 &      8.057 &        8.050 &     6.304 &       6.338 &     10.313 &       10.586 \\
#               Kalman Filter &               CUSUM &    66.967 &      64.798 &      8.057 &        8.050 &     6.304 &       6.338 &     10.313 &       10.586 \\
# Gaussian process regression &                BOCD &   128.631 &      83.495 &     10.509 &        9.138 &     8.202 &       7.341 &     13.148 &       11.842 \\
# Gaussian process regression &               CUSUM &   128.631 &      83.495 &     10.509 &        9.138 &     8.202 &       7.341 &     13.148 &       11.842 \\
#  Recursive ridge regression &                BOCD &  1063.720 &     289.335 &     27.859 &       17.010 &    20.513 &      12.939 &     32.139 &       18.521 \\
#  Recursive ridge regression &               CUSUM &  1063.720 &     289.335 &     27.859 &       17.010 &    20.513 &      12.939 &     32.139 &       18.521 \\
# \bottomrule
# \end{tabular}
#        composer                           piece                    reg_model  \
# 0      kapustin                      variations                Kalman Filter
# 1      kapustin                      variations                Kalman Filter
# 2      kapustin                      variations                  Bayesian LR
# 3      kapustin                      variations                  Bayesian LR
# 4      kapustin                      variations   Recursive ridge regression
# 5      kapustin                      variations   Recursive ridge regression
# 6      kapustin                      variations  Gaussian process regression
# 7      kapustin                      variations  Gaussian process regression
# 0          Bach                       BWV849-01                Kalman Filter
# 1          Bach                       BWV849-01                Kalman Filter
# 2          Bach                       BWV849-01                  Bayesian LR
# 3          Bach                       BWV849-01                  Bayesian LR
# 4          Bach                       BWV849-01   Recursive ridge regression
# 5          Bach                       BWV849-01   Recursive ridge regression
# 6          Bach                       BWV849-01  Gaussian process regression
# 7          Bach                       BWV849-01  Gaussian process regression
# 0     Beethoven                     Op027No1-01                Kalman Filter
# 1     Beethoven                     Op027No1-01                Kalman Filter
# 2     Beethoven                     Op027No1-01                  Bayesian LR
# 3     Beethoven                     Op027No1-01                  Bayesian LR
# 4     Beethoven                     Op027No1-01   Recursive ridge regression
# 5     Beethoven                     Op027No1-01   Recursive ridge regression
# 6     Beethoven                     Op027No1-01  Gaussian process regression
# 7     Beethoven                     Op027No1-01  Gaussian process regression
# 0        Chopin                        Op010-03                Kalman Filter
# 1        Chopin                        Op010-03                Kalman Filter
# 2        Chopin                        Op010-03                  Bayesian LR
# 3        Chopin                        Op010-03                  Bayesian LR
# 4        Chopin                        Op010-03   Recursive ridge regression
# 5        Chopin                        Op010-03   Recursive ridge regression
# 6        Chopin                        Op010-03  Gaussian process regression
# 7        Chopin                        Op010-03  Gaussian process regression
# 0         Haydn                   HobXVINo52-01                Kalman Filter
# 1         Haydn                   HobXVINo52-01                Kalman Filter
# 2         Haydn                   HobXVINo52-01                  Bayesian LR
# 3         Haydn                   HobXVINo52-01                  Bayesian LR
# 4         Haydn                   HobXVINo52-01   Recursive ridge regression
# 5         Haydn                   HobXVINo52-01   Recursive ridge regression
# 6         Haydn                   HobXVINo52-01  Gaussian process regression
# 7         Haydn                   HobXVINo52-01  Gaussian process regression
# 0         Liszt  AnnesDePelerinage-LectureDante                Kalman Filter
# 1         Liszt  AnnesDePelerinage-LectureDante                Kalman Filter
# 2         Liszt  AnnesDePelerinage-LectureDante                  Bayesian LR
# 3         Liszt  AnnesDePelerinage-LectureDante                  Bayesian LR
# 4         Liszt  AnnesDePelerinage-LectureDante   Recursive ridge regression
# 5         Liszt  AnnesDePelerinage-LectureDante   Recursive ridge regression
# 6         Liszt  AnnesDePelerinage-LectureDante  Gaussian process regression
# 7         Liszt  AnnesDePelerinage-LectureDante  Gaussian process regression
# 0        Mozart                           KV265                Kalman Filter
# 1        Mozart                           KV265                Kalman Filter
# 2        Mozart                           KV265                  Bayesian LR
# 3        Mozart                           KV265                  Bayesian LR
# 4        Mozart                           KV265   Recursive ridge regression
# 5        Mozart                           KV265   Recursive ridge regression
# 6        Mozart                           KV265  Gaussian process regression
# 7        Mozart                           KV265  Gaussian process regression
# 0  Rachmaninoff                        Op036-01                Kalman Filter
# 1  Rachmaninoff                        Op036-01                Kalman Filter
# 2  Rachmaninoff                        Op036-01                  Bayesian LR
# 3  Rachmaninoff                        Op036-01                  Bayesian LR
# 4  Rachmaninoff                        Op036-01   Recursive ridge regression
# 5  Rachmaninoff                        Op036-01   Recursive ridge regression
# 6  Rachmaninoff                        Op036-01  Gaussian process regression
# 7  Rachmaninoff                        Op036-01  Gaussian process regression
# 0         Ravel                        JeuxDEau                Kalman Filter
# 1         Ravel                        JeuxDEau                Kalman Filter
# 2         Ravel                        JeuxDEau                  Bayesian LR
# 3         Ravel                        JeuxDEau                  Bayesian LR
# 4         Ravel                        JeuxDEau   Recursive ridge regression
# 5         Ravel                        JeuxDEau   Recursive ridge regression
# 6         Ravel                        JeuxDEau  Gaussian process regression
# 7         Ravel                        JeuxDEau  Gaussian process regression
#
#   change_model       MSE    RMSE     MAE    MAPE
# 0        CUSUM    70.721   8.410   6.515  10.586
# 1         BOCD    70.721   8.410   6.515  10.586
# 2        CUSUM    89.785   9.475   7.037  11.353
# 3         BOCD    89.785   9.475   7.037  11.353
# 4        CUSUM   241.159  15.529  11.375  17.973
# 5         BOCD   241.159  15.529  11.375  17.973
# 6        CUSUM    77.017   8.776   7.097  11.795
# 7         BOCD    77.017   8.776   7.097  11.795
# 0        CUSUM    40.750   6.384   4.955   8.078
# 1         BOCD    40.750   6.384   4.955   8.078
# 2        CUSUM    53.533   7.317   5.795   9.226
# 3         BOCD    53.533   7.317   5.795   9.226
# 4        CUSUM   259.441  16.107  11.493  17.723
# 5         BOCD   259.441  16.107  11.493  17.723
# 6        CUSUM    39.663   6.298   4.939   8.188
# 7         BOCD    39.663   6.298   4.939   8.188
# 0        CUSUM    60.300   7.765   6.262  11.159
# 1         BOCD    60.300   7.765   6.262  11.159
# 2        CUSUM    63.319   7.957   6.250  11.119
# 3         BOCD    63.319   7.957   6.250  11.119
# 4        CUSUM  4028.291  63.469  47.450  82.929
# 5         BOCD  4028.291  63.469  47.450  82.929
# 6        CUSUM   116.261  10.782   8.567  14.987
# 7         BOCD   116.261  10.782   8.567  14.987
# 0        CUSUM    34.581   5.881   4.689   7.623
# 1         BOCD    34.581   5.881   4.689   7.623
# 2        CUSUM    29.736   5.453   4.169   6.786
# 3         BOCD    29.736   5.453   4.169   6.786
# 4        CUSUM   215.900  14.694  10.414  16.881
# 5         BOCD   215.900  14.694  10.414  16.881
# 6        CUSUM    54.988   7.415   5.616   8.716
# 7         BOCD    54.988   7.415   5.616   8.716
# 0        CUSUM    64.798   8.050   6.338   9.753
# 1         BOCD    64.798   8.050   6.338   9.753
# 2        CUSUM    39.532   6.287   4.734   7.292
# 3         BOCD    39.532   6.287   4.734   7.292
# 4        CUSUM   289.335  17.010  12.939  18.521
# 5         BOCD   289.335  17.010  12.939  18.521
# 6        CUSUM   115.621  10.753   8.119  12.865
# 7         BOCD   115.621  10.753   8.119  12.865
# 0        CUSUM    82.763   9.097   6.964  11.953
# 1         BOCD    82.763   9.097   6.964  11.953
# 2        CUSUM    55.674   7.461   5.509   9.319
# 3         BOCD    55.674   7.461   5.509   9.319
# 4        CUSUM   215.087  14.666  10.815  17.593
# 5         BOCD   215.087  14.666  10.815  17.593
# 6        CUSUM   462.401  21.504  16.421  24.764
# 7         BOCD   462.401  21.504  16.421  24.764
# 0        CUSUM    56.720   7.531   5.769   9.437
# 1         BOCD    56.720   7.531   5.769   9.437
# 2        CUSUM    47.010   6.856   4.923   8.005
# 3         BOCD    47.010   6.856   4.923   8.005
# 4        CUSUM  2002.369  44.748  33.366  49.967
# 5         BOCD  2002.369  44.748  33.366  49.967
# 6        CUSUM    59.801   7.733   5.697   9.672
# 7         BOCD    59.801   7.733   5.697   9.672
# 0        CUSUM    68.527   8.278   6.441  10.840
# 1         BOCD    68.527   8.278   6.441  10.840
# 2        CUSUM    60.002   7.746   5.667   9.369
# 3         BOCD    60.002   7.746   5.667   9.369
# 4        CUSUM   452.483  21.272  16.153  24.992
# 5         BOCD   452.483  21.272  16.153  24.992
# 6        CUSUM    83.495   9.138   7.341  11.842
# 7         BOCD    83.495   9.138   7.341  11.842
# 0        CUSUM   123.546  11.115   8.802  13.384
# 1         BOCD   123.546  11.115   8.802  13.384
# 2        CUSUM    72.892   8.538   5.926   8.729
# 3         BOCD    72.892   8.538   5.926   8.729
# 4        CUSUM  1869.412  43.237  30.608  42.674
# 5         BOCD  1869.412  43.237  30.608  42.674
# 6        CUSUM   148.432  12.183  10.022  15.502
# 7         BOCD   148.432  12.183  10.022  15.502
# (72, 8)
# \begin{tabular}{llllrrrr}
# \toprule
#     composer &                          piece &                   reg\_model & change\_model &      MSE &   RMSE &    MAE &   MAPE \\
# \midrule
#     kapustin &                     variations &               Kalman Filter &        CUSUM &   70.721 &  8.410 &  6.515 & 10.586 \\
#     kapustin &                     variations &               Kalman Filter &         BOCD &   70.721 &  8.410 &  6.515 & 10.586 \\
#     kapustin &                     variations &                 Bayesian LR &        CUSUM &   89.785 &  9.475 &  7.037 & 11.353 \\
#     kapustin &                     variations &                 Bayesian LR &         BOCD &   89.785 &  9.475 &  7.037 & 11.353 \\
#     kapustin &                     variations &  Recursive ridge regression &        CUSUM &  241.159 & 15.529 & 11.375 & 17.973 \\
#     kapustin &                     variations &  Recursive ridge regression &         BOCD &  241.159 & 15.529 & 11.375 & 17.973 \\
#     kapustin &                     variations & Gaussian process regression &        CUSUM &   77.017 &  8.776 &  7.097 & 11.795 \\
#     kapustin &                     variations & Gaussian process regression &         BOCD &   77.017 &  8.776 &  7.097 & 11.795 \\
#         Bach &                      BWV849-01 &               Kalman Filter &        CUSUM &   40.750 &  6.384 &  4.955 &  8.078 \\
#         Bach &                      BWV849-01 &               Kalman Filter &         BOCD &   40.750 &  6.384 &  4.955 &  8.078 \\
#         Bach &                      BWV849-01 &                 Bayesian LR &        CUSUM &   53.533 &  7.317 &  5.795 &  9.226 \\
#         Bach &                      BWV849-01 &                 Bayesian LR &         BOCD &   53.533 &  7.317 &  5.795 &  9.226 \\
#         Bach &                      BWV849-01 &  Recursive ridge regression &        CUSUM &  259.441 & 16.107 & 11.493 & 17.723 \\
#         Bach &                      BWV849-01 &  Recursive ridge regression &         BOCD &  259.441 & 16.107 & 11.493 & 17.723 \\
#         Bach &                      BWV849-01 & Gaussian process regression &        CUSUM &   39.663 &  6.298 &  4.939 &  8.188 \\
#         Bach &                      BWV849-01 & Gaussian process regression &         BOCD &   39.663 &  6.298 &  4.939 &  8.188 \\
#    Beethoven &                    Op027No1-01 &               Kalman Filter &        CUSUM &   60.300 &  7.765 &  6.262 & 11.159 \\
#    Beethoven &                    Op027No1-01 &               Kalman Filter &         BOCD &   60.300 &  7.765 &  6.262 & 11.159 \\
#    Beethoven &                    Op027No1-01 &                 Bayesian LR &        CUSUM &   63.319 &  7.957 &  6.250 & 11.119 \\
#    Beethoven &                    Op027No1-01 &                 Bayesian LR &         BOCD &   63.319 &  7.957 &  6.250 & 11.119 \\
#    Beethoven &                    Op027No1-01 &  Recursive ridge regression &        CUSUM & 4028.291 & 63.469 & 47.450 & 82.929 \\
#    Beethoven &                    Op027No1-01 &  Recursive ridge regression &         BOCD & 4028.291 & 63.469 & 47.450 & 82.929 \\
#    Beethoven &                    Op027No1-01 & Gaussian process regression &        CUSUM &  116.261 & 10.782 &  8.567 & 14.987 \\
#    Beethoven &                    Op027No1-01 & Gaussian process regression &         BOCD &  116.261 & 10.782 &  8.567 & 14.987 \\
#       Chopin &                       Op010-03 &               Kalman Filter &        CUSUM &   34.581 &  5.881 &  4.689 &  7.623 \\
#       Chopin &                       Op010-03 &               Kalman Filter &         BOCD &   34.581 &  5.881 &  4.689 &  7.623 \\
#       Chopin &                       Op010-03 &                 Bayesian LR &        CUSUM &   29.736 &  5.453 &  4.169 &  6.786 \\
#       Chopin &                       Op010-03 &                 Bayesian LR &         BOCD &   29.736 &  5.453 &  4.169 &  6.786 \\
#       Chopin &                       Op010-03 &  Recursive ridge regression &        CUSUM &  215.900 & 14.694 & 10.414 & 16.881 \\
#       Chopin &                       Op010-03 &  Recursive ridge regression &         BOCD &  215.900 & 14.694 & 10.414 & 16.881 \\
#       Chopin &                       Op010-03 & Gaussian process regression &        CUSUM &   54.988 &  7.415 &  5.616 &  8.716 \\
#       Chopin &                       Op010-03 & Gaussian process regression &         BOCD &   54.988 &  7.415 &  5.616 &  8.716 \\
#        Haydn &                  HobXVINo52-01 &               Kalman Filter &        CUSUM &   64.798 &  8.050 &  6.338 &  9.753 \\
#        Haydn &                  HobXVINo52-01 &               Kalman Filter &         BOCD &   64.798 &  8.050 &  6.338 &  9.753 \\
#        Haydn &                  HobXVINo52-01 &                 Bayesian LR &        CUSUM &   39.532 &  6.287 &  4.734 &  7.292 \\
#        Haydn &                  HobXVINo52-01 &                 Bayesian LR &         BOCD &   39.532 &  6.287 &  4.734 &  7.292 \\
#        Haydn &                  HobXVINo52-01 &  Recursive ridge regression &        CUSUM &  289.335 & 17.010 & 12.939 & 18.521 \\
#        Haydn &                  HobXVINo52-01 &  Recursive ridge regression &         BOCD &  289.335 & 17.010 & 12.939 & 18.521 \\
#        Haydn &                  HobXVINo52-01 & Gaussian process regression &        CUSUM &  115.621 & 10.753 &  8.119 & 12.865 \\
#        Haydn &                  HobXVINo52-01 & Gaussian process regression &         BOCD &  115.621 & 10.753 &  8.119 & 12.865 \\
#        Liszt & AnnesDePelerinage-LectureDante &               Kalman Filter &        CUSUM &   82.763 &  9.097 &  6.964 & 11.953 \\
#        Liszt & AnnesDePelerinage-LectureDante &               Kalman Filter &         BOCD &   82.763 &  9.097 &  6.964 & 11.953 \\
#        Liszt & AnnesDePelerinage-LectureDante &                 Bayesian LR &        CUSUM &   55.674 &  7.461 &  5.509 &  9.319 \\
#        Liszt & AnnesDePelerinage-LectureDante &                 Bayesian LR &         BOCD &   55.674 &  7.461 &  5.509 &  9.319 \\
#        Liszt & AnnesDePelerinage-LectureDante &  Recursive ridge regression &        CUSUM &  215.087 & 14.666 & 10.815 & 17.593 \\
#        Liszt & AnnesDePelerinage-LectureDante &  Recursive ridge regression &         BOCD &  215.087 & 14.666 & 10.815 & 17.593 \\
#        Liszt & AnnesDePelerinage-LectureDante & Gaussian process regression &        CUSUM &  462.401 & 21.504 & 16.421 & 24.764 \\
#        Liszt & AnnesDePelerinage-LectureDante & Gaussian process regression &         BOCD &  462.401 & 21.504 & 16.421 & 24.764 \\
#       Mozart &                          KV265 &               Kalman Filter &        CUSUM &   56.720 &  7.531 &  5.769 &  9.437 \\
#       Mozart &                          KV265 &               Kalman Filter &         BOCD &   56.720 &  7.531 &  5.769 &  9.437 \\
#       Mozart &                          KV265 &                 Bayesian LR &        CUSUM &   47.010 &  6.856 &  4.923 &  8.005 \\
#       Mozart &                          KV265 &                 Bayesian LR &         BOCD &   47.010 &  6.856 &  4.923 &  8.005 \\
#       Mozart &                          KV265 &  Recursive ridge regression &        CUSUM & 2002.369 & 44.748 & 33.366 & 49.967 \\
#       Mozart &                          KV265 &  Recursive ridge regression &         BOCD & 2002.369 & 44.748 & 33.366 & 49.967 \\
#       Mozart &                          KV265 & Gaussian process regression &        CUSUM &   59.801 &  7.733 &  5.697 &  9.672 \\
#       Mozart &                          KV265 & Gaussian process regression &         BOCD &   59.801 &  7.733 &  5.697 &  9.672 \\
# Rachmaninoff &                       Op036-01 &               Kalman Filter &        CUSUM &   68.527 &  8.278 &  6.441 & 10.840 \\
# Rachmaninoff &                       Op036-01 &               Kalman Filter &         BOCD &   68.527 &  8.278 &  6.441 & 10.840 \\
# Rachmaninoff &                       Op036-01 &                 Bayesian LR &        CUSUM &   60.002 &  7.746 &  5.667 &  9.369 \\
# Rachmaninoff &                       Op036-01 &                 Bayesian LR &         BOCD &   60.002 &  7.746 &  5.667 &  9.369 \\
# Rachmaninoff &                       Op036-01 &  Recursive ridge regression &        CUSUM &  452.483 & 21.272 & 16.153 & 24.992 \\
# Rachmaninoff &                       Op036-01 &  Recursive ridge regression &         BOCD &  452.483 & 21.272 & 16.153 & 24.992 \\
# Rachmaninoff &                       Op036-01 & Gaussian process regression &        CUSUM &   83.495 &  9.138 &  7.341 & 11.842 \\
# Rachmaninoff &                       Op036-01 & Gaussian process regression &         BOCD &   83.495 &  9.138 &  7.341 & 11.842 \\
#        Ravel &                       JeuxDEau &               Kalman Filter &        CUSUM &  123.546 & 11.115 &  8.802 & 13.384 \\
#        Ravel &                       JeuxDEau &               Kalman Filter &         BOCD &  123.546 & 11.115 &  8.802 & 13.384 \\
#        Ravel &                       JeuxDEau &                 Bayesian LR &        CUSUM &   72.892 &  8.538 &  5.926 &  8.729 \\
#        Ravel &                       JeuxDEau &                 Bayesian LR &         BOCD &   72.892 &  8.538 &  5.926 &  8.729 \\
#        Ravel &                       JeuxDEau &  Recursive ridge regression &        CUSUM & 1869.412 & 43.237 & 30.608 & 42.674 \\
#        Ravel &                       JeuxDEau &  Recursive ridge regression &         BOCD & 1869.412 & 43.237 & 30.608 & 42.674 \\
#        Ravel &                       JeuxDEau & Gaussian process regression &        CUSUM &  148.432 & 12.183 & 10.022 & 15.502 \\
#        Ravel &                       JeuxDEau & Gaussian process regression &         BOCD &  148.432 & 12.183 & 10.022 & 15.502 \\
# \bottomrule
# \end{tabular}

# %%
""" Kapustin table(s) """

df_kapustin = pd.read_csv(
    "results/core1/chow/kapustin_variations/pitch_mean/step3/structural_breaks_precision_recall.csv",
    index_col=0).reset_index(drop=True)
display(df_kapustin.head())

df_kapustin_agg = df_kapustin.groupby(['pred_model', 'change_model']).agg({
    "precision": [np.mean, np.median],
    "recall": [np.mean, np.median],
    "f1": [np.mean, np.median]
}).round(3).reset_index()
df_kapustin_agg.columns = ['Model', 'Change point method', 'Precision mean', 'Precision median',
                           'Recall mean', "Recall median",
                           'F1 Score mean', 'F1 Score median']
df_kapustin_agg['Model'] = df_kapustin_agg['Model'].str.replace("Bayesian LR", "Bayesian linear regression")
display(df_kapustin_agg)
print(df_kapustin_agg.to_latex(index=False))
# Out:
#    margin model_no     pred_model change_model  precision    recall        f1
# 0     0.1      all            all          all   0.142012  0.676056  0.234719
# 1     0.1        1  Kalman Filter        CUSUM   0.052632  0.500000  0.095238
# 2     0.1        2  Kalman Filter         BOCD   0.142857  0.500000  0.222222
# 3     0.1        3    Bayesian LR        CUSUM   0.133333  0.500000  0.210526
# 4     0.1        4    Bayesian LR         BOCD   0.177778  0.500000  0.262295
#                          Model Change point method  Precision mean  \
# 0   Bayesian linear regression                BOCD           0.647
# 1   Bayesian linear regression               CUSUM           0.564
# 2  Gaussian process regression                BOCD           0.605
# 3  Gaussian process regression               CUSUM           0.462
# 4                Kalman Filter                BOCD           0.671
# 5                Kalman Filter               CUSUM           0.503
# 6   Recursive ridge regression                BOCD           0.686
# 7   Recursive ridge regression               CUSUM           0.545
# 8                          all                 all           0.586
#
#    Precision median  Recall mean  Recall median  F1 Score mean  \
# 0             0.689        0.456          0.455          0.506
# 1             0.575        0.450          0.442          0.470
# 2             0.704        0.443          0.463          0.478
# 3             0.444        0.460          0.460          0.438
# 4             0.771        0.451          0.474          0.508
# 5             0.526        0.428          0.429          0.419
# 6             0.792        0.460          0.478          0.523
# 7             0.542        0.455          0.444          0.464
# 8             0.626        0.659          0.663          0.595
#
#    F1 Score median
# 0            0.538
# 1            0.503
# 2            0.510
# 3            0.452
# 4            0.540
# 5            0.462
# 6            0.551
# 7            0.488
# 8            0.630
# \begin{tabular}{llrrrrrr}
# \toprule
#                       Model & Change point method &  Precision mean &  Precision median &  Recall mean &  Recall median &  F1 Score mean &  F1 Score median \\
# \midrule
#  Bayesian linear regression &                BOCD &           0.647 &             0.689 &        0.456 &          0.455 &          0.506 &            0.538 \\
#  Bayesian linear regression &               CUSUM &           0.564 &             0.575 &        0.450 &          0.442 &          0.470 &            0.503 \\
# Gaussian process regression &                BOCD &           0.605 &             0.704 &        0.443 &          0.463 &          0.478 &            0.510 \\
# Gaussian process regression &               CUSUM &           0.462 &             0.444 &        0.460 &          0.460 &          0.438 &            0.452 \\
#               Kalman Filter &                BOCD &           0.671 &             0.771 &        0.451 &          0.474 &          0.508 &            0.540 \\
#               Kalman Filter &               CUSUM &           0.503 &             0.526 &        0.428 &          0.429 &          0.419 &            0.462 \\
#  Recursive ridge regression &                BOCD &           0.686 &             0.792 &        0.460 &          0.478 &          0.523 &            0.551 \\
#  Recursive ridge regression &               CUSUM &           0.545 &             0.542 &        0.455 &          0.444 &          0.464 &            0.488 \\
#                         all &                 all &           0.586 &             0.626 &        0.659 &          0.663 &          0.595 &            0.630 \\
# \bottomrule
# \end{tabular}

# %%
# """ Summary of error (cumulative) - use error paths"""
# import fnmatch
# import os

# matches = []
# for root, dirnames, filenames in os.walk('results'):
#     for filename in fnmatch.filter(filenames, 'summary_error_cumulative.csv'):
#         matches.append(os.path.join(root, filename))
# print("\n".join(matches))

# all_summary_error = []
# for match in matches:
#     raise Exception()
#     df_curr = pd.read_csv(match, header=[0,1], skiprows=1)
#     df_curr.columns = ["model_no", "reg_model", "change_model", "n", "MSE", "RMSE", "MAE", "MAPE", "analysis_key"]
#     all_summary_error.append(df_curr)

# df_all_summary_error = pd.concat(all_summary_error)
# display(df_all_summary_error.head(25))
# print(df_all_summary_error.shape)
